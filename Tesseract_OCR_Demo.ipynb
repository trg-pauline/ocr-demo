# %% [markdown]
# ## OCR with Tesseract

# %% [markdown]
# This notebook demonstrates the use of Tesseract OCR for extracting text from images.

# %% [markdown]
# ### Install pytesseract

# %% [markdown]
# Uncomment and run the following cell if you don't have pytesseract installed.

# %% [markdown]
# ### Load an Image

# %% [markdown]
# Provide the path to the image you want to inspect with Tesseract.

# %% [markdown]
# ### Apply Tesseract OCR

# %% [markdown]
# Extract text from the image using Tesseract OCR.

# %%
# !pip3 install pytesseract
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from PIL import Image
import pytesseract

# %%
# Provide the path to your image
image_path = 'photo.png'
image = Image.open(image_path)
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=353x167>

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = '/usr/bin/tesseract'  # Replace with the actual path

# %%
text = pytesseract.image_to_string(image)

# %%
print('Extracted Text:\n', text)
# Out:
# Extracted Text:
#  us
# @ redhat
